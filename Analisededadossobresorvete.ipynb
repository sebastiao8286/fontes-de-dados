# %% [markdown]
# <a href="https://colab.research.google.com/github/sebastiao8286/fontes-de-dados/blob/main/Analisededadossobresorvete.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Análise de dados sobre sorvete

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("sakshisatre/ice-cream-sales-dataset")

print("caminho para os arquivos conjuntos de dados:", path)
# Out:
# ...
# 100%|██████████| 2.09k/2.09k [00:00<00:00, 1.51MB/s]
# Extracting files...
# caminho para os arquivos conjuntos de dados: /root/.cache/kagglehub/datasets/sakshisatre/ice-cream-sales-dataset/versions/1

# %%
# Out:
#    Temperature  Revenue
# 0         24.6      535
# 1         26.1      626
# 2         27.8      661
# 3         20.6      488
# 4         11.6      317

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create a scatter plot of Temperature vs Revenue
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Temperature', y='Revenue', data=df)
plt.title('Revenue vs Temperature')
plt.xlabel('Temperature (°C)')
plt.ylabel('Revenue')
plt.grid(True)
plt.show()

# %%
from sklearn.linear_model import LinearRegression
import numpy as np

# Prepare the data for the model
# Reshape the temperature data to be a 2D array
X = df['Temperature'].values.reshape(-1, 1)
y = df['Revenue'].values

# Create and train the linear regression model
model = LinearRegression()
model.fit(X, y)

# Display the model coefficients
print("Coeficiente (slope):", model.coef_[0])
print("Intercept:", model.intercept_)

# You can also make predictions with the model
# For example, predict revenue for a temperature of 25 degrees
predicted_revenue = model.predict([[25]])
print("Predicted Revenue for 25 degrees:", predicted_revenue[0])
# Out:
# Coeficiente (slope): 21.441960923612957
# Intercept: 44.296803484425595
# Predicted Revenue for 25 degrees: 580.3458265747495
